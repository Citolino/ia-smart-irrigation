# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

df = pd.read_csv('data_smart.csv', sep = ';', encoding = 'utf-8',engine='c')


df
# Out:
#              timeInstant  humidity  humiditySoil  temperature  Liga  \
# 0    30-03-2022T21:26:49      73.0         92.26        27.90     0
# 1    29-03-2022T17:33:22      76.6         91.01        25.90     0
# 2    28-03-2022T18:15:21      92.2         83.98        25.32     0
# 3    29-03-2022T17:29:21      76.0         83.81        25.93     0
# 4    01-04-2022T10:30:14      88.0          8.57        20.40     1
# ..                   ...       ...           ...          ...   ...
# 393  28-03-2022T15:45:15      27.0         50.00        39.70     1
# 394  28-03-2022T15:14:14      29.2         51.00        39.18     1
# 395  28-03-2022T15:26:15      19.0         60.00        43.46     1
# 396  28-03-2022T15:29:15      23.5         59.00        40.67     1
# 397  28-03-2022T15:25:15      19.0         50.00        43.42     1
#
#      HumidityIdeal
# 0               50
# 1               50
# 2               50
# 3               50
# 4               50
# ..             ...
# 393             50
# 394             50
# 395             50
# 396             50
# 397             50
#
# [398 rows x 6 columns]

# %%
from pycaret.classification import *
s = setup(df, target = 'Liga')
# Out:
# <style  type="text/css" >
# #T_cdebe_row44_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_cdebe_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cdebe_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_cdebe_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_cdebe_row0_col1" class="data row0 col1" >1450</td>
#             </tr>
#             <tr>
#                         <th id="T_cdebe_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_cdebe_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_cdebe_row1_col1" class="data row1 col1" >Liga</td>
#             </tr>
#             <tr>
#                         <th id="T_cdebe_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_cdebe_row2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_cdebe_row2_col1" class="data row2 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_cdebe_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_cdebe_row3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_cdebe_row3_col1" class="data row3 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_cdebe_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_cdebe_row4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_cdebe_row4_col1" class="data row4 col1" >(398, 6)</td>
#             </tr>
#             <tr>
#                         <th id="T_cdebe_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_cdebe_row5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_cdebe_row5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_cdebe_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_cdebe_row6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_cdebe_row6_col1" class="data row6 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_cdebe_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_cdebe_row7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_cdebe_row7_col1" class="data row7 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_cdebe_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_cdebe_row8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_cdebe_row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_cdebe_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_cdebe_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_cdebe_row9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_cdebe_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_cdebe_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_cdebe_row10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_cdebe_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_cdebe_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_cdebe_row11_col1" class="data row11 col1" >(278, 17)</td>
#             </tr>
#             <tr>
#                         <th id="T_cdebe_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_cdebe_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_cdebe_row12_col1" class="data row12 col1" >(120, 17)</td>
#             </tr>
#             <tr>
#                         <th id="T_cdebe_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_cdebe_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_cdebe_row13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_cdebe_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_cdebe_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_cdebe_row14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_cdebe_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_cdebe_row15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_cdebe_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_cdebe_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_cdebe_row16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_cdebe_row16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_cdebe_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_cdebe_row17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_cdebe_row17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_cdebe_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_cdebe_row18_col0" class="data row18 col0" >Use GPU</td>
#                         <td id="T_cdebe_row18_col1" class="data row18 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_cdebe_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_cdebe_row19_col0" class="data row19 col0" >Log Experiment</td>
#                         <td id="T_cdebe_row19_col1" class="data row19 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_cdebe_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_cdebe_row20_col0" class="data row20 col0" >Experiment Name</td>
#                         <td id="T_cdebe_row20_col1" class="data row20 col1" >clf-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_cdebe_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_cdebe_row21_col0" class="data row21 col0" >USI</td>
#                         <td id="T_cdebe_row21_col1" class="data row21 col1" >5a03</td>
#             </tr>
#             <tr>
#                         <th id="T_cdebe_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_cdebe_row22_col0" class="data row22 col0" >Imputation Type</td>
#                         <td id="T_cdebe_row22_col1" class="data row22 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_cdebe_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_cdebe_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_cdebe_row23_col1" class="data row23 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_cdebe_level0_row24" class="row_heading level0 row24" >24</th>

# %%
best = compare_models()
# Out:
# <style  type="text/css" >
#     #T_ca99e_ th {
#           text-align: left;
#     }#T_ca99e_row0_col0,#T_ca99e_row0_col3,#T_ca99e_row1_col0,#T_ca99e_row1_col1,#T_ca99e_row1_col2,#T_ca99e_row1_col3,#T_ca99e_row1_col4,#T_ca99e_row1_col5,#T_ca99e_row1_col6,#T_ca99e_row1_col7,#T_ca99e_row2_col0,#T_ca99e_row2_col1,#T_ca99e_row2_col2,#T_ca99e_row2_col3,#T_ca99e_row2_col4,#T_ca99e_row2_col5,#T_ca99e_row2_col6,#T_ca99e_row2_col7,#T_ca99e_row3_col0,#T_ca99e_row3_col1,#T_ca99e_row3_col2,#T_ca99e_row3_col3,#T_ca99e_row3_col4,#T_ca99e_row3_col5,#T_ca99e_row3_col6,#T_ca99e_row3_col7,#T_ca99e_row4_col0,#T_ca99e_row4_col1,#T_ca99e_row4_col2,#T_ca99e_row4_col3,#T_ca99e_row4_col4,#T_ca99e_row4_col5,#T_ca99e_row4_col6,#T_ca99e_row4_col7,#T_ca99e_row5_col0,#T_ca99e_row5_col1,#T_ca99e_row5_col2,#T_ca99e_row5_col3,#T_ca99e_row5_col4,#T_ca99e_row5_col5,#T_ca99e_row5_col6,#T_ca99e_row5_col7,#T_ca99e_row6_col0,#T_ca99e_row6_col1,#T_ca99e_row6_col2,#T_ca99e_row6_col3,#T_ca99e_row6_col4,#T_ca99e_row6_col5,#T_ca99e_row6_col6,#T_ca99e_row6_col7,#T_ca99e_row7_col0,#T_ca99e_row7_col1,#T_ca99e_row7_col2,#T_ca99e_row7_col3,#T_ca99e_row7_col4,#T_ca99e_row7_col5,#T_ca99e_row7_col6,#T_ca99e_row7_col7,#T_ca99e_row8_col0,#T_ca99e_row8_col1,#T_ca99e_row8_col2,#T_ca99e_row8_col3,#T_ca99e_row8_col4,#T_ca99e_row8_col5,#T_ca99e_row8_col6,#T_ca99e_row8_col7,#T_ca99e_row9_col0,#T_ca99e_row9_col1,#T_ca99e_row9_col2,#T_ca99e_row9_col3,#T_ca99e_row9_col4,#T_ca99e_row9_col5,#T_ca99e_row9_col6,#T_ca99e_row9_col7,#T_ca99e_row10_col0,#T_ca99e_row10_col1,#T_ca99e_row10_col2,#T_ca99e_row10_col4,#T_ca99e_row10_col5,#T_ca99e_row10_col6,#T_ca99e_row10_col7,#T_ca99e_row11_col0,#T_ca99e_row11_col1,#T_ca99e_row11_col2,#T_ca99e_row11_col3,#T_ca99e_row11_col4,#T_ca99e_row11_col5,#T_ca99e_row11_col6,#T_ca99e_row11_col7,#T_ca99e_row12_col0,#T_ca99e_row12_col1,#T_ca99e_row12_col2,#T_ca99e_row12_col3,#T_ca99e_row12_col4,#T_ca99e_row12_col5,#T_ca99e_row12_col6,#T_ca99e_row12_col7,#T_ca99e_row13_col0,#T_ca99e_row13_col1,#T_ca99e_row13_col2,#T_ca99e_row13_col3,#T_ca99e_row13_col4,#T_ca99e_row13_col5,#T_ca99e_row13_col6,#T_ca99e_row13_col7{
#             text-align:  left;
#             text-align:  left;
#         }#T_ca99e_row0_col1,#T_ca99e_row0_col2,#T_ca99e_row0_col4,#T_ca99e_row0_col5,#T_ca99e_row0_col6,#T_ca99e_row0_col7,#T_ca99e_row10_col3{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_ca99e_row0_col8,#T_ca99e_row1_col8,#T_ca99e_row2_col8,#T_ca99e_row3_col8,#T_ca99e_row4_col8,#T_ca99e_row5_col8,#T_ca99e_row6_col8,#T_ca99e_row7_col8,#T_ca99e_row8_col8,#T_ca99e_row9_col8,#T_ca99e_row10_col8,#T_ca99e_row11_col8,#T_ca99e_row12_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_ca99e_row13_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_ca99e_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ca99e_level0_row0" class="row_heading level0 row0" >knn</th>
#                         <td id="T_ca99e_row0_col0" class="data row0 col0" >K Neighbors Classifier</td>
#                         <td id="T_ca99e_row0_col1" class="data row0 col1" >0.9890</td>
#                         <td id="T_ca99e_row0_col2" class="data row0 col2" >0.9974</td>
#                         <td id="T_ca99e_row0_col3" class="data row0 col3" >0.9764</td>
#                         <td id="T_ca99e_row0_col4" class="data row0 col4" >0.9889</td>
#                         <td id="T_ca99e_row0_col5" class="data row0 col5" >0.9816</td>
#                         <td id="T_ca99e_row0_col6" class="data row0 col6" >0.9738</td>
#                         <td id="T_ca99e_row0_col7" class="data row0 col7" >0.9748</td>
#                         <td id="T_ca99e_row0_col8" class="data row0 col8" >0.0100</td>
#             </tr>
#             <tr>
#                         <th id="T_ca99e_level0_row1" class="row_heading level0 row1" >rf</th>
#                         <td id="T_ca99e_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#                         <td id="T_ca99e_row1_col1" class="data row1 col1" >0.9856</td>
#                         <td id="T_ca99e_row1_col2" class="data row1 col2" >0.9965</td>
#                         <td id="T_ca99e_row1_col3" class="data row1 col3" >0.9764</td>
#                         <td id="T_ca99e_row1_col4" class="data row1 col4" >0.9778</td>
#                         <td id="T_ca99e_row1_col5" class="data row1 col5" >0.9763</td>
#                         <td id="T_ca99e_row1_col6" class="data row1 col6" >0.9660</td>
#                         <td id="T_ca99e_row1_col7" class="data row1 col7" >0.9667</td>
#                         <td id="T_ca99e_row1_col8" class="data row1 col8" >0.0490</td>
#             </tr>
#             <tr>
#                         <th id="T_ca99e_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#                         <td id="T_ca99e_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#                         <td id="T_ca99e_row2_col1" class="data row2 col1" >0.9856</td>
#                         <td id="T_ca99e_row2_col2" class="data row2 col2" >0.9955</td>
#                         <td id="T_ca99e_row2_col3" class="data row2 col3" >0.9778</td>
#                         <td id="T_ca99e_row2_col4" class="data row2 col4" >0.9764</td>
#                         <td id="T_ca99e_row2_col5" class="data row2 col5" >0.9765</td>
#                         <td id="T_ca99e_row2_col6" class="data row2 col6" >0.9661</td>
#                         <td id="T_ca99e_row2_col7" class="data row2 col7" >0.9667</td>
#                         <td id="T_ca99e_row2_col8" class="data row2 col8" >0.0810</td>
#             </tr>
#             <tr>
#                         <th id="T_ca99e_level0_row3" class="row_heading level0 row3" >dt</th>
#                         <td id="T_ca99e_row3_col0" class="data row3 col0" >Decision Tree Classifier</td>
#                         <td id="T_ca99e_row3_col1" class="data row3 col1" >0.9820</td>
#                         <td id="T_ca99e_row3_col2" class="data row3 col2" >0.9810</td>
#                         <td id="T_ca99e_row3_col3" class="data row3 col3" >0.9778</td>
#                         <td id="T_ca99e_row3_col4" class="data row3 col4" >0.9678</td>
#                         <td id="T_ca99e_row3_col5" class="data row3 col5" >0.9719</td>
#                         <td id="T_ca99e_row3_col6" class="data row3 col6" >0.9587</td>
#                         <td id="T_ca99e_row3_col7" class="data row3 col7" >0.9596</td>
#                         <td id="T_ca99e_row3_col8" class="data row3 col8" >0.0040</td>
#             </tr>
#             <tr>
#                         <th id="T_ca99e_level0_row4" class="row_heading level0 row4" >ada</th>
#                         <td id="T_ca99e_row4_col0" class="data row4 col0" >Ada Boost Classifier</td>
#                         <td id="T_ca99e_row4_col1" class="data row4 col1" >0.9819</td>
#                         <td id="T_ca99e_row4_col2" class="data row4 col2" >0.9965</td>
#                         <td id="T_ca99e_row4_col3" class="data row4 col3" >0.9764</td>
#                         <td id="T_ca99e_row4_col4" class="data row4 col4" >0.9689</td>
#                         <td id="T_ca99e_row4_col5" class="data row4 col5" >0.9710</td>
#                         <td id="T_ca99e_row4_col6" cla

# %%
print(best)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=-1, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
evaluate_model(best)

# %%
plot_model(best, plot = 'auc')

# %%
plot_model(best, plot = 'confusion_matrix')

# %%
predict_model(best)

# %%
predictions = predict_model(best, data=df)
predictions.head()

# %%
predictions = predict_model(best, data=df, raw_score=True)
predictions.head()
